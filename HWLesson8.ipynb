# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Необходимые данные:
# ФИО ученика
# год рождения
# класс
# место в классе (ряд, парта, вариант)
# статус по оценкам (отличник, ударник, троечник или двоечник)
# и другие данные, которые захочется хранить

# %%
studentData = {'Фамилия' : ['Иванов', 'Петров', 'Васечкин', 'Сколова'],
       'Имя' : ['Иван', 'Петр', 'Василий', 'Наталья'],
       'Отчество' : ['Иванович', 'Петрович', 'Васильевич', 'Олеговна'],
       'Пол' : ['M','M','M','F'],
       'Год рождения' : [2006,2005,2006,2005],
       'Класс' : ['10А','10А','10А','10Б'],
       'Статус' : ['Хорошист','Хорошист','Двоечник','Отличник'],
       'id ученика' : [0,1,2,3]
       }

classData = {
    'Номер кабинета' : ['101','101','101','101'],
    'Номер ряда' : [1,1,1,1],
    'Номер парты' : [1,1,2,2],
    'Номер варианта' : [1,2,1,2],
    'id ученика' : [0,1,2,3]
}

addressData = {
    'Город' : ['Москва','Москва','Москва','Москва'],
    'Улица' : ['Московская','Ленинградска','Московская','Дальневосточная'],
    'Дом' : ['1','10','3','7'],
    'Квартира' : [101,32,6,'-'],
    'Примечание' : ['Ученик','Ученик','Ученик','Школа'],
    'id ученика' : [0,1,2,3]
}

phoneData = {
    'Номер телефона' : [89998881122,87773334412,82223334455,86543457623],
    'Примечание' : ['Номер матери','Ученик','Номер матери','Ученик'],
    'id ученика' : [0,0,1,1]
}

# %% [markdown]
# Ячейкой ниже можно считать данные из сохраненных .csv файлов.

# %%
# studentsDF = pd.read_csv('studentData.csv')
# classDF = pd.read_csv('classData.csv')
# addresDF = pd.read_csv('addressData.csv')
# phoneDF = pd.read_csv('phoneData.csv')

# %%
studentsDF = pd.DataFrame(studentData)
studentsDF['id ученика'] = studentsDF.index
addresDF = pd.DataFrame(addressData)
classDF = pd.DataFrame(classData)
phoneDF = pd.DataFrame(phoneData)

# %%
studentsDF.to_csv('studentData.csv')

# %%
classDF.to_csv('classData.csv')

# %%
addresDF.to_csv('addressData.csv')

# %%
phoneDF.to_csv('phoneData.csv')

# %%
studentsDF.tail()
# Out:
#     Фамилия      Имя    Отчество Пол  Год рождения Класс    Статус  id ученика
# 0    Иванов     Иван    Иванович   M          2006   10А  Хорошист           0
# 1    Петров     Петр    Петрович   M          2005   10А  Хорошист           1
# 2  Васечкин  Василий  Васильевич   M          2006   10А  Двоечник           2
# 3   Сколова  Наталья    Олеговна   F          2005   10Б  Отличник           3

# %%
addresDF.tail()
# Out:
#     Город            Улица Дом Квартира Примечание  id ученика
# 0  Москва       Московская   1      101     Ученик           0
# 1  Москва     Ленинградска  10       32     Ученик           1
# 2  Москва       Московская   3        6     Ученик           2
# 3  Москва  Дальневосточная   7        -      Школа           3

# %%
classDF.tail()
# Out:
#   Номер кабинета  Номер ряда  Номер парты  Номер варианта  id ученика
# 0            101           1            1               1           0
# 1            101           1            1               2           1
# 2            101           1            2               1           2
# 3            101           1            2               2           3

# %%
phoneDF.tail()
# Out:
#    Номер телефона    Примечание  id ученика
# 0     89998881122  Номер матери           0
# 1     87773334412        Ученик           0
# 2     82223334455  Номер матери           1
# 3     86543457623        Ученик           1

# %%
# def appendStudent():
#     studRow = {'Фамилия' : input('Введите фамилию: '),
#        'Имя' : input('Введите имя: '),
#        'Отчество' : input('Введите отчество: '),
#        'Пол' : input('Введите пол ("F" или "M"): '),
#        'Год рождения' : int(input('Введите год рождения: ')),
#        'Класс' : input('Введите класс: '),
#         'Статус' : input('Введите статус: '),
#        }

#     return(studRow)

# %%
# def appendClassData():
    
#     classRow = {
#         'Номер кабинета' : input('Введите номер кабинета: '),
#         'Номер ряда' : int(input('Введите номер ряда: ')),
#         'Номер парты' : int(input('Введите номер парты: ')),
#         'Номер варианта' : int(input('Введите номер варианта: ')),
#         'id ученика' : input('Введите id ученика: ')
#     }
    
#     return(classRow)

# %%
# def appendAdressData():
#     adressRow = {
#         'Город' : input('Введите город: '),
#         'Улица' : input('Введите улицу: '),
#         'Дом' : input('Введите номер дом: '),
#         'Квартира' : int(input('Введите номер квартиры: ')),
#         'Примечание' : input('Введите примечание: '),
#         'id ученика' : input('Введите id ученика: ')
#     }
    
#     return(adressRow)

# %%
# def appendPhoneData():
#     phoneRow = {
#         'Номер телефона' : int(input('Введите номер телефона: ')),
#         'Примечание' : input('Введите примечание: '),
#         'id ученика' : input('Введите id ученика: ')
#     }
    
#     return(phoneRow)

# %%
# studentsDF = studentsDF.append(appendStudent(), ignore_index = True)
# studentsDF['id ученика'] = studentsDF.index

# %%
# classDF = classDF.append(appendClassData(), ignore_index = True)

# %%
# addresDF = addresDF.append(appendAdressData(), ignore_index = True)

# %%
# phoneDF = phoneDF.append(appendPhoneData(), ignore_index = True)

# %%
def deleteRow(rowIndex, df):
    df = df.drop([rowIndex])
    return df

# %%
# Удали символ решетки ниже и запусти, если хочешь удалить какую-нибудь строку
# phoneDF = deleteRow(1, phoneDF)

# %%
resultPhone = studentsDF.merge(phoneDF, left_on=studentsDF.index, right_on='id ученика', how='inner')

# %%
resultPhone.head()
# Out:
#    id ученика Фамилия   Имя  Отчество Пол  Год рождения Класс    Статус  \
# 0           0  Иванов  Иван  Иванович   M          2006   10А  Хорошист
# 1           0  Иванов  Иван  Иванович   M          2006   10А  Хорошист
# 2           1  Петров  Петр  Петрович   M          2005   10А  Хорошист
# 3           1  Петров  Петр  Петрович   M          2005   10А  Хорошист
#
#    id ученика_x  Номер телефона    Примечание  id ученика_y
# 0             0     89998881122  Номер матери             0
# 1             0     87773334412        Ученик             0
# 2             1     82223334455  Номер матери             1
# 3             1     86543457623        Ученик             1

# %%
resultClass = studentsDF.merge(classDF, left_on=studentsDF.index, right_on='id ученика', how='inner')

# %%
resultClass.head()
# Out:
#    id ученика   Фамилия      Имя    Отчество Пол  Год рождения Класс  \
# 0           0    Иванов     Иван    Иванович   M          2006   10А
# 1           1    Петров     Петр    Петрович   M          2005   10А
# 2           2  Васечкин  Василий  Васильевич   M          2006   10А
# 3           3   Сколова  Наталья    Олеговна   F          2005   10Б
#
#      Статус  id ученика_x Номер кабинета  Номер ряда  Номер парты  \
# 0  Хорошист             0            101           1            1
# 1  Хорошист             1            101           1            1
# 2  Двоечник             2            101           1            2
# 3  Отличник             3            101           1            2
#
#    Номер варианта  id ученика_y
# 0               1             0
# 1               2             1
# 2               1             2
# 3               2             3

# %%
table = pd.pivot_table(studentsDF, values = 'id ученика', index = ['Фамилия','Имя','Отчество'], columns=['Статус'], aggfunc=np.sum)

# %%
table.head()
# Out:
# Статус                       Двоечник  Отличник  Хорошист
# Фамилия  Имя     Отчество
# Васечкин Василий Васильевич       2.0       NaN       NaN
# Иванов   Иван    Иванович         NaN       NaN       0.0
# Петров   Петр    Петрович         NaN       NaN       1.0
# Сколова  Наталья Олеговна         NaN       3.0       NaN
